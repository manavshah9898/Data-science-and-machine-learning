# %%
from bs4 import BeautifulSoup
import csv
import request

with open('/content/sample_data/sample-example.html') as html_file:
    soup = BeautifulSoup(html_file, 'lxml')

table1=soup.find("table",attrs={"class":"num_rows"})
table_data = table1.tbody.find_all("tr")

print(table1)
print(table_data)

for table heading in Zip(table_data[1].find_all("table"),table_data):
  t_headers = []
  for th in table.find_all("th"):
    t.headers.append(th.text.replace('\n').strip)

csv_file = open('demo_exam.csv','w')
csv_writer = csv.writer(csv_file)

csv_writer.writerow(['NAME','SEM','BRANCH'])

for table in soup.find_all("table"):
  headline = table.tr.text
  print(headline)

  data1=table.tr.td.find('table',class_='num_rows').text
  print(data1)
# Out:
#   File "<ipython-input-3-a464a211e976>", line 14
#     for table heading in Zip(table_data[1].find_all("table"),table_data):
#                     ^
# SyntaxError: invalid syntax
