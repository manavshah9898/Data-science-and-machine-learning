# %%
largest = None
smallest = None

while True:
    inp = input("Enter a number: ")
    if inp == "done" : break
    try:
        num = float(inp)
    except:
        print ("Invalid input")
        continue
    if smallest is None:
        smallest = num 
    if num > largest :
        largest = num
    elif num < smallest :
        smallest = num

def done(largest,smallest):
    print ("Maximum is", int(largest))  
    print ("Minimum is", int(smallest))

done(largest,smallest)
# Out:
# Enter a number: 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-98317b9fe7dd> in <module>()
#      12     if smallest is None:
#      13         smallest = num
# ---> 14     if num > largest :
#      15         largest = num
#      16     elif num < smallest :
#
# TypeError: '>' not supported between instances of 'float' and 'NoneType'
